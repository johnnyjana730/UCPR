# %% [markdown]
# # Running UCPR

# %%
import os
import sys
sys.path.insert(0,'/home/johnnyjana730/github/UCPR/')
print(sys.path)

from config import get_hparams

# !export PYTHONPATH="./"
os.environ["CUDA_VISIBLE_DEVICES"]="3"

from config import get_hparams

# cell_core, beauty_core, cloth_core, MovieLens-1M_core, amazon-book_20core

DATASET = "cell_core"

locals().update(get_hparams(DATASET))

epochs=100
KGE_pretrained=1
kg_emb_grad=0
tri_wd_rm=1
tri_pro_rm=0
batch_size=32
load_pretrain_model=0

train_file="train.py"
test_file="test.py"

exp_name=f"note_rm_w{tri_wd_rm}_p{tri_pro_rm}"
# Out:
# ['/home/johnnyjana730/github/UCPR/', '/home/johnnyjana730/github/UCPR/bash', '/home/johnnyjana730/anaconda3_tmp/lib/python38.zip', '/home/johnnyjana730/anaconda3_tmp/lib/python3.8', '/home/johnnyjana730/anaconda3_tmp/lib/python3.8/lib-dynload', '', '/home/johnnyjana730/anaconda3_tmp/lib/python3.8/site-packages', '/home/johnnyjana730/anaconda3_tmp/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg', '/home/johnnyjana730/anaconda3_tmp/lib/python3.8/site-packages/IPython/extensions', '/home/johnnyjana730/.ipython']
# dataset =  cell_core

# %% [markdown]
# # Train LSTM

# %%
command = f"python3 ../src/{train_file} --reasoning_step {reasoning_step} \
                                         --batch_size {batch_size} \
                                         --name {exp_name} \
                                         --lr {lr} \
                                         --embed_size {embed_size} \
                                         --n_memory {n_memory} \
                                         --load_pretrain_model {load_pretrain_model}  \
                                         --tri_wd_rm {tri_wd_rm} \
                                         --tri_pro_rm {tri_pro_rm} \
                                         --gp_setting {gp_setting} \
                                         --epochs {epochs} \
                                         --KGE_pretrained {KGE_pretrained} \
                                         --lambda_num {lambda_num}  \
                                         --kg_emb_grad {kg_emb_grad} \
                                         --p_hop {p_hop}  \
                                         --reasoning_step {reasoning_step}  \
                                         --model lstm \
                                         --dataset {DATASET}"
print("Running Command:")
print(' '.join(command.split()))
# !{command}
# Out:
# Running Command:
# python3 ../src/train.py --reasoning_step 2 --batch_size 32 --name note_rm_w1_p0 --lr 0.0001 --embed_size 32 --n_memory 64 --load_pretrain_model 0 --tri_wd_rm 1 --tri_pro_rm 0 --gp_setting 6_800_15_500_50 --epochs 100 --KGE_pretrained 1 --lambda_num 2.0 --kg_emb_grad 0 --p_hop 2 --reasoning_step 2 --model lstm --dataset cell_core
# args.gp_setting =  6_800_15_500_50 args.att_core =  0 args.item_core =  0 args.user_core_th =  6 args.kg_fre_upper =  500 args.max_acts =  50
# len(self.core_user_list) =  6548
# self.args.core_user_list =  6548
# self.user_triplet_list =  6548
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# env.output_valid_user() =  6548
# args.batch_size =  32
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# self.embeds[key] =  (27879, 100)
# weight =  (27880, 32)
# key =  user
# self.embeds[key] =  torch.Size([27880, 32])
# vocab_size + 1 =  27880
# embed =  torch.Size([27880, 32])
# embed.requires_grad =  False
# self.embeds[key] =  (10429, 100)
# weight =  (10430, 32)
# key =  product
# self.embeds[key] =  torch.Size([10430, 32])
# vocab_size + 1 =  10430
# embed =  torch.Size([10430, 32])
# embed.requires_grad =  False
# self.embeds[key] =  (22493, 100)
# weight =  (22494, 32)
# key =  word
# self.embeds[key] =  torch.Size([22494, 32])
# vocab_size + 1 =  22494
# embed =  torch.Size([22494, 32])
# embed.requires_grad =  False
# self.embeds[key] =  (101287, 100)
# weight =  (101288, 32)
# key =  related_product
# self.embeds[key] =  torch.Size([101288, 32])
# vocab_size + 1 =  101288
# embed =  torch.Size([101288, 32])
# embed.requires_grad =  False
# self.embeds[key] =  (955, 100)
# weight =  (956, 32)
# key =  brand
# self.embeds[key] =  torch.Size([956, 32])
# vocab_size + 1 =  956
# embed =  torch.Size([956, 32])
# embed.requires_grad =  False
# self.embeds[key] =  (206, 100)
# weight =  (207, 32)
# key =  category
# self.embeds[key] =  torch.Size([207, 32])
# vocab_size + 1 =  207
# embed =  torch.Size([207, 32])
# embed.requires_grad =  False
# r =  setup self_loop
# key =  self_loop
# self_loop embed =  torch.Size([1, 32])
# r =  setup purchase
# key =  purchase
# purchase embed =  torch.Size([1, 32])
# r =  setup mentions
# key =  mentions
# mentions embed =  torch.Size([1, 32])
# r =  setup described_as
# key =  described_as
# described_as embed =  torch.Size([1, 32])
# r =  setup produced_by
# key =  produced_by
# produced_by embed =  torch.Size([1, 32])
# r =  setup belongs_to
# key =  belongs_to
# belongs_to embed =  torch.Size([1, 32])
# r =  setup also_bought
# key =  also_bought
# also_bought embed =  torch.Size([1, 32])
# r =  setup also_viewed
# key =  also_viewed
# also_viewed embed =  torch.Size([1, 32])
# r =  setup bought_together
# key =  bought_together
# bought_together embed =  torch.Size([1, 32])
# r =  setup padding
# key =  padding
# padding embed =  torch.Size([1, 32])
# [INFO]  Namespace(KGE_pretrained=True, act_dropout=0.5, add_products=False, att_core=0, att_evaluation=False, batch_size=32, best_model_epoch=0, best_save_model_dir='', core_user_list='', dataset='cell_core', device=device(type='cuda', index=0), embed_size=32, ent_weight=0.001, envir='p1', epochs=100, eva_epochs=0, gamma=0.99, gp_setting='6_800_15_500_50', gpu='0', gradient_plot='gradient_plot/', h0_embbed=0, hidden=[64, 32], item_core=0, kg_emb_grad=False, kg_fre_dict='', kg_fre_lower=15, kg_fre_upper=500, kg_no_grad=False, l2_lambda=0, l2_weight=1e-06, lambda_num=2.0, load_pretrain_model=False, load_pt_emb_size=False, log_dir='../eva/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300', logger=<Logger ../eva/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/train_log.txt (DEBUG)>, lr=0.0001, max_acts=50, max_path_len=3, model='lstm', n_memory=64, name='note_rm_w1_p0', non_sampling=True, p_hop=2, pretest=False, pretrained_dir='../eva/Amazon_Cellphones_Core/pretrained/note_rm_w1_p0_g_aiu_0_0_300', pretrained_st_epoch=0, reasoning_step=2, reward_hybrid=False, reward_rh='', run_eval=True, run_path=True, sam_type='alet', save_model_dir='../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300', seed=52, sort_by='score', state_history=1, state_rg=False, sub_batch_size=1, test_lstm_up=True, topk=[10, 10, 1], topk_list=[1, 10, 100, 100], topk_string='10, 10, 1', training=True, tri_pro_rm=False, tri_wd_rm=True, user_core=300, user_core_th=6)
# [INFO]  Parameters:['kg_emb.self_loop', 'kg_emb.purchase', 'kg_emb.mentions', 'kg_emb.described_as', 'kg_emb.produced_by', 'kg_emb.belongs_to', 'kg_emb.also_bought', 'kg_emb.also_viewed', 'kg_emb.bought_together', 'kg_emb.padding', 'kg_emb.user.weight', 'kg_emb.product.weight', 'kg_emb.word.weight', 'kg_emb.related_product.weight', 'kg_emb.brand.weight', 'kg_emb.category.weight', 'kg_emb.self_loop_bias.weight', 'kg_emb.purchase_bias.weight', 'kg_emb.mentions_bias.weight', 'kg_emb.described_as_bias.weight', 'kg_emb.produced_by_bias.weight', 'kg_emb.belongs_to_bias.weight', 'kg_emb.also_bought_bias.weight', 'kg_emb.also_viewed_bias.weight', 'kg_emb.bought_together_bias.weight', 'kg_emb.padding_bias.weight', 'state_lstm.policy_lstm.lstm.weight_ih_l0', 'state_lstm.policy_lstm.lstm.weight_hh_l0', 'state_lstm.policy_lstm.lstm.bias_ih_l0', 'state_lstm.policy_lstm.lstm.bias_hh_l0', 'transfor_state.weight', 'transfor_state.bias', 'state_tr_query.weight', 'state_tr_query.bias', 'l1.weight', 'l1.bias', 'l2.weight', 'l2.bias', 'actor.weight', 'actor.bias', 'critic.weight', 'critic.bias']
# [INFO]  epoch/step=0/100 | loss=0.07365 | ploss=0.06237 | vloss=0.01930 | entropy=-9.46000 | reward=0.00656
# [INFO]  epoch/step=0/200 | loss=0.07805 | ploss=0.06494 | vloss=0.02114 | entropy=-9.45629 | reward=0.00719
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_0.ckpt
# [INFO]  epoch/step=1/300 | loss=0.08793 | ploss=0.07206 | vloss=0.02389 | entropy=-9.44841 | reward=0.00813
# [INFO]  epoch/step=1/400 | loss=0.06786 | ploss=0.05657 | vloss=0.01930 | entropy=-9.42416 | reward=0.00656
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_1.ckpt
# [INFO]  epoch/step=2/500 | loss=0.09170 | ploss=0.07484 | vloss=0.02481 | entropy=-9.36059 | reward=0.00844
# [INFO]  epoch/step=2/600 | loss=0.14003 | ploss=0.11023 | vloss=0.03768 | entropy=-9.28937 | reward=0.01281
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_2.ckpt
# [INFO]  epoch/step=3/700 | loss=0.12873 | ploss=0.10161 | vloss=0.03492 | entropy=-9.21046 | reward=0.01188
# [INFO]  epoch/step=3/800 | loss=0.13110 | ploss=0.10113 | vloss=0.03768 | entropy=-9.10064 | reward=0.01281
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_3.ckpt
# [INFO]  epoch/step=4/900 | loss=0.22502 | ploss=0.16999 | vloss=0.06249 | entropy=-8.85042 | reward=0.02125
# [INFO]  epoch/step=4/1000 | loss=0.22029 | ploss=0.16310 | vloss=0.06433 | entropy=-8.53319 | reward=0.02187
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_4.ckpt
# [INFO]  epoch/step=5/1100 | loss=0.27675 | ploss=0.19912 | vloss=0.08436 | entropy=-8.11933 | reward=0.02813
# [INFO]  epoch/step=5/1200 | loss=0.33748 | ploss=0.24268 | vloss=0.10109 | entropy=-7.67516 | reward=0.03438
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_5.ckpt
# [INFO]  epoch/step=6/1300 | loss=0.37185 | ploss=0.26394 | vloss=0.11395 | entropy=-7.42899 | reward=0.03875
# [INFO]  epoch/step=6/1400 | loss=0.42624 | ploss=0.29508 | vloss=0.13693 | entropy=-7.14461 | reward=0.04656
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_6.ckpt
# [INFO]  epoch/step=7/1500 | loss=0.38757 | ploss=0.26566 | vloss=0.12737 | entropy=-6.83288 | reward=0.04312
# [INFO]  epoch/step=7/1600 | loss=0.50671 | ploss=0.34285 | vloss=0.16909 | entropy=-6.59292 | reward=0.05750
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_7.ckpt
# [INFO]  epoch/step=8/1700 | loss=0.57668 | ploss=0.38556 | vloss=0.19629 | entropy=-6.54495 | reward=0.06656
# [INFO]  epoch/step=8/1800 | loss=0.63107 | ploss=0.41928 | vloss=0.21688 | entropy=-6.44876 | reward=0.07375
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_8.ckpt
# [INFO]  epoch/step=9/1900 | loss=0.66269 | ploss=0.43617 | vloss=0.23158 | entropy=-6.42222 | reward=0.07875
# [INFO]  epoch/step=9/2000 | loss=0.71282 | ploss=0.46795 | vloss=0.24996 | entropy=-6.44630 | reward=0.08500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_9.ckpt
# [INFO]  epoch/step=10/2100 | loss=0.79581 | ploss=0.51598 | vloss=0.28488 | entropy=-6.40320 | reward=0.09688
# [INFO]  epoch/step=10/2200 | loss=0.85895 | ploss=0.54504 | vloss=0.31888 | entropy=-6.32697 | reward=0.10844
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_10.ckpt
# [INFO]  epoch/step=11/2300 | loss=0.90836 | ploss=0.57345 | vloss=0.33983 | entropy=-6.28117 | reward=0.11500
# [INFO]  epoch/step=11/2400 | loss=0.95520 | ploss=0.59611 | vloss=0.36391 | entropy=-6.18413 | reward=0.12375
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_11.ckpt
# [INFO]  epoch/step=12/2500 | loss=1.02730 | ploss=0.63058 | vloss=0.40141 | entropy=-6.03736 | reward=0.13594
# [INFO]  epoch/step=12/2600 | loss=1.18362 | ploss=0.71949 | vloss=0.46867 | entropy=-5.89430 | reward=0.15937
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_12.ckpt
# [INFO]  epoch/step=13/2700 | loss=1.26287 | ploss=0.76189 | vloss=0.50543 | entropy=-5.79694 | reward=0.17094
# [INFO]  epoch/step=13/2800 | loss=1.28989 | ploss=0.77130 | vloss=0.52289 | entropy=-5.64852 | reward=0.17781
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_13.ckpt
# [INFO]  epoch/step=14/2900 | loss=1.34882 | ploss=0.80057 | vloss=0.55248 | entropy=-5.57192 | reward=0.18750
# [INFO]  epoch/step=14/3000 | loss=1.31832 | ploss=0.77014 | vloss=0.55230 | entropy=-5.47118 | reward=0.18781
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_14.ckpt
# [INFO]  epoch/step=15/3100 | loss=1.36121 | ploss=0.79733 | vloss=0.56792 | entropy=-5.38547 | reward=0.19219
# [INFO]  epoch/step=15/3200 | loss=1.36462 | ploss=0.79241 | vloss=0.57619 | entropy=-5.32805 | reward=0.19594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_15.ckpt
# [INFO]  epoch/step=16/3300 | loss=1.44105 | ploss=0.83439 | vloss=0.61056 | entropy=-5.24358 | reward=0.20594
# [INFO]  epoch/step=16/3400 | loss=1.60073 | ploss=0.93285 | vloss=0.67177 | entropy=-5.21988 | reward=0.22844
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_16.ckpt
# [INFO]  epoch/step=17/3500 | loss=1.58859 | ploss=0.91515 | vloss=0.67728 | entropy=-5.17449 | reward=0.22937
# [INFO]  epoch/step=17/3600 | loss=1.65524 | ploss=0.95049 | vloss=0.70852 | entropy=-5.11047 | reward=0.24094
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_17.ckpt
# [INFO]  epoch/step=18/3700 | loss=1.54372 | ploss=0.89248 | vloss=0.65504 | entropy=-5.13236 | reward=0.22219
# [INFO]  epoch/step=18/3800 | loss=1.68209 | ploss=0.96074 | vloss=0.72507 | entropy=-5.05264 | reward=0.24656
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_18.ckpt
# [INFO]  epoch/step=19/3900 | loss=1.54911 | ploss=0.88491 | vloss=0.66791 | entropy=-5.03866 | reward=0.22656
# [INFO]  epoch/step=19/4000 | loss=1.64227 | ploss=0.94204 | vloss=0.70393 | entropy=-5.02986 | reward=0.23938
# [INFO]  epoch/step=19/4100 | loss=1.65880 | ploss=0.93682 | vloss=0.72562 | entropy=-4.97407 | reward=0.24563
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_19.ckpt
# [INFO]  epoch/step=20/4200 | loss=1.64784 | ploss=0.92914 | vloss=0.72231 | entropy=-4.93961 | reward=0.24563
# [INFO]  epoch/step=20/4300 | loss=1.64121 | ploss=0.92160 | vloss=0.72323 | entropy=-4.94274 | reward=0.24594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_20.ckpt
# [INFO]  epoch/step=21/4400 | loss=1.62497 | ploss=0.91009 | vloss=0.71845 | entropy=-4.89763 | reward=0.24375
# [INFO]  epoch/step=21/4500 | loss=1.58825 | ploss=0.88510 | vloss=0.70669 | entropy=-4.86195 | reward=0.24031
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_21.ckpt
# [INFO]  epoch/step=22/4600 | loss=1.69839 | ploss=0.94430 | vloss=0.75760 | entropy=-4.82838 | reward=0.25688
# [INFO]  epoch/step=22/4700 | loss=1.72054 | ploss=0.95856 | vloss=0.76550 | entropy=-4.84607 | reward=0.26031
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_22.ckpt
# [INFO]  epoch/step=23/4800 | loss=1.72051 | ploss=0.94966 | vloss=0.77432 | entropy=-4.79468 | reward=0.26219
# [INFO]  epoch/step=23/4900 | loss=1.57974 | ploss=0.87188 | vloss=0.71128 | entropy=-4.74499 | reward=0.24188
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_23.ckpt
# [INFO]  epoch/step=24/5000 | loss=1.80254 | ploss=0.99524 | vloss=0.81071 | entropy=-4.73193 | reward=0.27437
# [INFO]  epoch/step=24/5100 | loss=1.74970 | ploss=0.96187 | vloss=0.79123 | entropy=-4.72271 | reward=0.26906
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_24.ckpt
# [INFO]  epoch/step=25/5200 | loss=1.78635 | ploss=0.97371 | vloss=0.81604 | entropy=-4.72466 | reward=0.27656
# [INFO]  epoch/step=25/5300 | loss=1.66493 | ploss=0.91658 | vloss=0.75172 | entropy=-4.67877 | reward=0.25562
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_25.ckpt
# [INFO]  epoch/step=26/5400 | loss=1.68476 | ploss=0.92833 | vloss=0.75980 | entropy=-4.68538 | reward=0.25688
# [INFO]  epoch/step=26/5500 | loss=1.63559 | ploss=0.88999 | vloss=0.74896 | entropy=-4.67361 | reward=0.25469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_26.ckpt
# [INFO]  epoch/step=27/5600 | loss=1.71072 | ploss=0.93735 | vloss=0.77671 | entropy=-4.65238 | reward=0.26281
# [INFO]  epoch/step=27/5700 | loss=1.77543 | ploss=0.96731 | vloss=0.81145 | entropy=-4.63396 | reward=0.27594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_27.ckpt
# [INFO]  epoch/step=28/5800 | loss=1.65346 | ploss=0.89716 | vloss=0.75962 | entropy=-4.62778 | reward=0.25719
# [INFO]  epoch/step=28/5900 | loss=1.68539 | ploss=0.90021 | vloss=0.78847 | entropy=-4.60173 | reward=0.26813
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_28.ckpt
# [INFO]  epoch/step=29/6000 | loss=1.78803 | ploss=0.96829 | vloss=0.82303 | entropy=-4.59231 | reward=0.27875
# [INFO]  epoch/step=29/6100 | loss=1.63830 | ploss=0.89079 | vloss=0.75080 | entropy=-4.58503 | reward=0.25531
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_29.ckpt
# [INFO]  epoch/step=30/6200 | loss=1.73976 | ploss=0.93944 | vloss=0.80355 | entropy=-4.53453 | reward=0.27250
# [INFO]  epoch/step=30/6300 | loss=1.75918 | ploss=0.95003 | vloss=0.81237 | entropy=-4.51847 | reward=0.27625
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_30.ckpt
# [INFO]  epoch/step=31/6400 | loss=1.67957 | ploss=0.90225 | vloss=0.78057 | entropy=-4.55913 | reward=0.26469
# [INFO]  epoch/step=31/6500 | loss=1.75150 | ploss=0.93775 | vloss=0.81696 | entropy=-4.51395 | reward=0.27781
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_31.ckpt
# [INFO]  epoch/step=32/6600 | loss=1.74028 | ploss=0.93056 | vloss=0.81292 | entropy=-4.50264 | reward=0.27531
# [INFO]  epoch/step=32/6700 | loss=1.73070 | ploss=0.92891 | vloss=0.80502 | entropy=-4.52641 | reward=0.27375
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_32.ckpt
# [INFO]  epoch/step=33/6800 | loss=1.67734 | ploss=0.90092 | vloss=0.77965 | entropy=-4.52674 | reward=0.26438
# [INFO]  epoch/step=33/6900 | loss=1.79317 | ploss=0.95825 | vloss=0.83810 | entropy=-4.47383 | reward=0.28500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_33.ckpt
# [INFO]  epoch/step=34/7000 | loss=1.77058 | ploss=0.96913 | vloss=0.80465 | entropy=-4.49689 | reward=0.27250
# [INFO]  epoch/step=34/7100 | loss=1.77218 | ploss=0.94643 | vloss=0.82891 | entropy=-4.45201 | reward=0.28187
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_34.ckpt
# [INFO]  epoch/step=35/7200 | loss=1.82539 | ploss=0.97811 | vloss=0.85041 | entropy=-4.43437 | reward=0.28844
# [INFO]  epoch/step=35/7300 | loss=1.69189 | ploss=0.90289 | vloss=0.79215 | entropy=-4.44139 | reward=0.26937
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_35.ckpt
# [INFO]  epoch/step=36/7400 | loss=1.71522 | ploss=0.91412 | vloss=0.80428 | entropy=-4.47845 | reward=0.27313
# [INFO]  epoch/step=36/7500 | loss=1.80345 | ploss=0.96388 | vloss=0.84269 | entropy=-4.41113 | reward=0.28656
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_36.ckpt
# [INFO]  epoch/step=37/7600 | loss=1.76204 | ploss=0.93150 | vloss=0.83369 | entropy=-4.43289 | reward=0.28219
# [INFO]  epoch/step=37/7700 | loss=1.74916 | ploss=0.91969 | vloss=0.83258 | entropy=-4.40417 | reward=0.28313
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_37.ckpt
# [INFO]  epoch/step=38/7800 | loss=1.82514 | ploss=0.96881 | vloss=0.85942 | entropy=-4.37862 | reward=0.29094
# [INFO]  epoch/step=38/7900 | loss=1.81309 | ploss=0.95879 | vloss=0.85740 | entropy=-4.37962 | reward=0.29156
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_38.ckpt
# [INFO]  epoch/step=39/8000 | loss=1.73533 | ploss=0.91429 | vloss=0.82413 | entropy=-4.37929 | reward=0.27969
# [INFO]  epoch/step=39/8100 | loss=1.81618 | ploss=0.95540 | vloss=0.86383 | entropy=-4.33222 | reward=0.29375
# [INFO]  epoch/step=39/8200 | loss=1.74753 | ploss=0.91047 | vloss=0.84012 | entropy=-4.34278 | reward=0.28437
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_39.ckpt
# [INFO]  epoch/step=40/8300 | loss=1.70897 | ploss=0.88677 | vloss=0.82523 | entropy=-4.32341 | reward=0.28063
# [INFO]  epoch/step=40/8400 | loss=1.79053 | ploss=0.93522 | vloss=0.85832 | entropy=-4.28407 | reward=0.29187
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_40.ckpt
# [INFO]  epoch/step=41/8500 | loss=1.74641 | ploss=0.90946 | vloss=0.83994 | entropy=-4.27696 | reward=0.28469
# [INFO]  epoch/step=41/8600 | loss=1.80621 | ploss=0.94172 | vloss=0.86751 | entropy=-4.29444 | reward=0.29500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_41.ckpt
# [INFO]  epoch/step=42/8700 | loss=1.76750 | ploss=0.92929 | vloss=0.84122 | entropy=-4.28800 | reward=0.28437
# [INFO]  epoch/step=42/8800 | loss=1.72698 | ploss=0.89093 | vloss=0.83902 | entropy=-4.24762 | reward=0.28531
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_42.ckpt
# [INFO]  epoch/step=43/8900 | loss=1.65427 | ploss=0.85926 | vloss=0.79803 | entropy=-4.30468 | reward=0.27063
# [INFO]  epoch/step=43/9000 | loss=1.77338 | ploss=0.91893 | vloss=0.85740 | entropy=-4.22133 | reward=0.29156
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_43.ckpt
# [INFO]  epoch/step=44/9100 | loss=1.80633 | ploss=0.94345 | vloss=0.86585 | entropy=-4.25012 | reward=0.29313
# [INFO]  epoch/step=44/9200 | loss=1.75709 | ploss=0.89987 | vloss=0.86015 | entropy=-4.21243 | reward=0.29250
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_44.ckpt
# [INFO]  epoch/step=45/9300 | loss=1.71691 | ploss=0.88026 | vloss=0.83957 | entropy=-4.19399 | reward=0.28437
# [INFO]  epoch/step=45/9400 | loss=1.83211 | ploss=0.94550 | vloss=0.88956 | entropy=-4.22173 | reward=0.30250
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_45.ckpt
# [INFO]  epoch/step=46/9500 | loss=1.77182 | ploss=0.91125 | vloss=0.86346 | entropy=-4.16360 | reward=0.29250
# [INFO]  epoch/step=46/9600 | loss=1.75172 | ploss=0.89632 | vloss=0.85832 | entropy=-4.19735 | reward=0.29187
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_46.ckpt
# [INFO]  epoch/step=47/9700 | loss=1.72995 | ploss=0.88370 | vloss=0.84913 | entropy=-4.14493 | reward=0.28687
# [INFO]  epoch/step=47/9800 | loss=1.92116 | ploss=0.99867 | vloss=0.92540 | entropy=-4.17785 | reward=0.31469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_47.ckpt
# [INFO]  epoch/step=48/9900 | loss=1.74199 | ploss=0.88800 | vloss=0.85685 | entropy=-4.12577 | reward=0.29063
# [INFO]  epoch/step=48/10000 | loss=1.76238 | ploss=0.88669 | vloss=0.87853 | entropy=-4.11774 | reward=0.29875
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_48.ckpt
# [INFO]  epoch/step=49/10100 | loss=1.82817 | ploss=0.94293 | vloss=0.88809 | entropy=-4.11821 | reward=0.30125
# [INFO]  epoch/step=49/10200 | loss=1.94511 | ploss=0.99496 | vloss=0.95297 | entropy=-4.09113 | reward=0.32406
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_49.ckpt
# [INFO]  epoch/step=50/10300 | loss=1.73686 | ploss=0.88582 | vloss=0.85390 | entropy=-4.13635 | reward=0.28906
# [INFO]  epoch/step=50/10400 | loss=1.90219 | ploss=0.98605 | vloss=0.91897 | entropy=-4.09593 | reward=0.31250
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_50.ckpt
# [INFO]  epoch/step=51/10500 | loss=1.78884 | ploss=0.90727 | vloss=0.88441 | entropy=-4.10899 | reward=0.30000
# [INFO]  epoch/step=51/10600 | loss=1.82462 | ploss=0.92499 | vloss=0.90243 | entropy=-4.05302 | reward=0.30688
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_51.ckpt
# [INFO]  epoch/step=52/10700 | loss=1.79418 | ploss=0.91148 | vloss=0.88552 | entropy=-4.08337 | reward=0.30000
# [INFO]  epoch/step=52/10800 | loss=1.78043 | ploss=0.90564 | vloss=0.87761 | entropy=-4.09185 | reward=0.29844
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_52.ckpt
# [INFO]  epoch/step=53/10900 | loss=1.81760 | ploss=0.92700 | vloss=0.89342 | entropy=-4.08469 | reward=0.30156
# [INFO]  epoch/step=53/11000 | loss=1.93571 | ploss=0.98095 | vloss=0.95756 | entropy=-4.07203 | reward=0.32562
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_53.ckpt
# [INFO]  epoch/step=54/11100 | loss=1.81274 | ploss=0.90757 | vloss=0.90794 | entropy=-4.02424 | reward=0.30688
# [INFO]  epoch/step=54/11200 | loss=1.90226 | ploss=0.96676 | vloss=0.93827 | entropy=-4.02932 | reward=0.31906
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_54.ckpt
# [INFO]  epoch/step=55/11300 | loss=1.87852 | ploss=0.94615 | vloss=0.93514 | entropy=-4.03383 | reward=0.31688
# [INFO]  epoch/step=55/11400 | loss=1.69211 | ploss=0.84763 | vloss=0.84729 | entropy=-4.06109 | reward=0.28813
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_55.ckpt
# [INFO]  epoch/step=56/11500 | loss=1.83493 | ploss=0.92020 | vloss=0.91750 | entropy=-4.03032 | reward=0.31125
# [INFO]  epoch/step=56/11600 | loss=1.86392 | ploss=0.94498 | vloss=0.92172 | entropy=-4.03572 | reward=0.31344
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_56.ckpt
# [INFO]  epoch/step=57/11700 | loss=1.85440 | ploss=0.92548 | vloss=0.93165 | entropy=-3.98271 | reward=0.31531
# [INFO]  epoch/step=57/11800 | loss=1.81244 | ploss=0.90815 | vloss=0.90702 | entropy=-3.98574 | reward=0.30844
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_57.ckpt
# [INFO]  epoch/step=58/11900 | loss=1.84214 | ploss=0.93108 | vloss=0.91382 | entropy=-4.01839 | reward=0.31000
# [INFO]  epoch/step=58/12000 | loss=1.94525 | ploss=0.99227 | vloss=0.95573 | entropy=-4.00205 | reward=0.32500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_58.ckpt
# [INFO]  epoch/step=59/12100 | loss=1.80800 | ploss=0.90588 | vloss=0.90482 | entropy=-3.95617 | reward=0.30656
# [INFO]  epoch/step=59/12200 | loss=1.96384 | ploss=0.98325 | vloss=0.98330 | entropy=-3.95678 | reward=0.33437
# [INFO]  epoch/step=59/12300 | loss=1.82867 | ploss=0.90765 | vloss=0.92375 | entropy=-3.97992 | reward=0.31281
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_59.ckpt
# [INFO]  epoch/step=60/12400 | loss=1.80542 | ploss=0.90661 | vloss=0.90151 | entropy=-3.94171 | reward=0.30656
# [INFO]  epoch/step=60/12500 | loss=1.73595 | ploss=0.86656 | vloss=0.87210 | entropy=-3.95223 | reward=0.29656
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_60.ckpt
# [INFO]  epoch/step=61/12600 | loss=1.77825 | ploss=0.87522 | vloss=0.90573 | entropy=-3.94826 | reward=0.30688
# [INFO]  epoch/step=61/12700 | loss=1.82626 | ploss=0.90725 | vloss=0.92172 | entropy=-3.95774 | reward=0.31344
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_61.ckpt
# [INFO]  epoch/step=62/12800 | loss=1.81628 | ploss=0.90310 | vloss=0.91584 | entropy=-3.91016 | reward=0.31031
# [INFO]  epoch/step=62/12900 | loss=1.85127 | ploss=0.91844 | vloss=0.93551 | entropy=-3.92942 | reward=0.31812
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_62.ckpt
# [INFO]  epoch/step=63/13000 | loss=1.78321 | ploss=0.88895 | vloss=0.89691 | entropy=-3.90278 | reward=0.30406
# [INFO]  epoch/step=63/13100 | loss=1.81386 | ploss=0.90489 | vloss=0.91162 | entropy=-3.89477 | reward=0.31000
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_63.ckpt
# [INFO]  epoch/step=64/13200 | loss=1.80564 | ploss=0.89042 | vloss=0.91786 | entropy=-3.89711 | reward=0.31062
# [INFO]  epoch/step=64/13300 | loss=1.82130 | ploss=0.90500 | vloss=0.91897 | entropy=-3.91634 | reward=0.31250
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_64.ckpt
# [INFO]  epoch/step=65/13400 | loss=1.81235 | ploss=0.88738 | vloss=0.92761 | entropy=-3.87745 | reward=0.31469
# [INFO]  epoch/step=65/13500 | loss=1.84154 | ploss=0.91511 | vloss=0.92908 | entropy=-3.89004 | reward=0.31594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_65.ckpt
# [INFO]  epoch/step=66/13600 | loss=1.74316 | ploss=0.84946 | vloss=0.89636 | entropy=-3.90396 | reward=0.30406
# [INFO]  epoch/step=66/13700 | loss=1.77432 | ploss=0.86166 | vloss=0.91529 | entropy=-3.87668 | reward=0.31125
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_66.ckpt
# [INFO]  epoch/step=67/13800 | loss=1.90983 | ploss=0.93648 | vloss=0.97594 | entropy=-3.82847 | reward=0.33000
# [INFO]  epoch/step=67/13900 | loss=1.86956 | ploss=0.91741 | vloss=0.95481 | entropy=-3.89417 | reward=0.32469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_67.ckpt
# [INFO]  epoch/step=68/14000 | loss=1.80367 | ploss=0.88604 | vloss=0.92025 | entropy=-3.86111 | reward=0.31219
# [INFO]  epoch/step=68/14100 | loss=1.82441 | ploss=0.89336 | vloss=0.93367 | entropy=-3.86184 | reward=0.31750
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_68.ckpt
# [INFO]  epoch/step=69/14200 | loss=1.81648 | ploss=0.87453 | vloss=0.94451 | entropy=-3.81045 | reward=0.32062
# [INFO]  epoch/step=69/14300 | loss=1.89135 | ploss=0.92255 | vloss=0.97135 | entropy=-3.79141 | reward=0.33031
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_69.ckpt
# [INFO]  epoch/step=70/14400 | loss=1.78940 | ploss=0.86804 | vloss=0.92393 | entropy=-3.80418 | reward=0.31344
# [INFO]  epoch/step=70/14500 | loss=1.86354 | ploss=0.90025 | vloss=0.96583 | entropy=-3.78540 | reward=0.32844
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_70.ckpt
# [INFO]  epoch/step=71/14600 | loss=1.79404 | ploss=0.87620 | vloss=0.92044 | entropy=-3.83945 | reward=0.31188
# [INFO]  epoch/step=71/14700 | loss=1.80721 | ploss=0.88071 | vloss=0.92908 | entropy=-3.80870 | reward=0.31594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_71.ckpt
# [INFO]  epoch/step=72/14800 | loss=1.86547 | ploss=0.91765 | vloss=0.95040 | entropy=-3.80900 | reward=0.32188
# [INFO]  epoch/step=72/14900 | loss=1.76056 | ploss=0.84414 | vloss=0.91897 | entropy=-3.77984 | reward=0.31250
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_72.ckpt
# [INFO]  epoch/step=73/15000 | loss=1.84221 | ploss=0.89879 | vloss=0.94599 | entropy=-3.80531 | reward=0.32000
# [INFO]  epoch/step=73/15100 | loss=1.80427 | ploss=0.88140 | vloss=0.92540 | entropy=-3.76389 | reward=0.31469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_73.ckpt
# [INFO]  epoch/step=74/15200 | loss=1.86246 | ploss=0.91518 | vloss=0.94984 | entropy=-3.79811 | reward=0.32094
# [INFO]  epoch/step=74/15300 | loss=1.84012 | ploss=0.88784 | vloss=0.95481 | entropy=-3.75533 | reward=0.32469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_74.ckpt
# [INFO]  epoch/step=75/15400 | loss=1.84672 | ploss=0.89534 | vloss=0.95389 | entropy=-3.74287 | reward=0.32250
# [INFO]  epoch/step=75/15500 | loss=1.97471 | ploss=0.95990 | vloss=1.01730 | entropy=-3.71897 | reward=0.34594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_75.ckpt
# [INFO]  epoch/step=76/15600 | loss=1.85564 | ploss=0.89157 | vloss=0.96657 | entropy=-3.73034 | reward=0.32812
# [INFO]  epoch/step=76/15700 | loss=1.90963 | ploss=0.92704 | vloss=0.98513 | entropy=-3.77030 | reward=0.33500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_76.ckpt
# [INFO]  epoch/step=77/15800 | loss=1.89572 | ploss=0.91750 | vloss=0.98072 | entropy=-3.72422 | reward=0.33219
# [INFO]  epoch/step=77/15900 | loss=1.88715 | ploss=0.91463 | vloss=0.97502 | entropy=-3.72720 | reward=0.33156
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_77.ckpt
# [INFO]  epoch/step=78/16000 | loss=1.83787 | ploss=0.87158 | vloss=0.96878 | entropy=-3.71858 | reward=0.32812
# [INFO]  epoch/step=78/16100 | loss=1.76369 | ploss=0.85553 | vloss=0.91070 | entropy=-3.76958 | reward=0.30969
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_78.ckpt
# [INFO]  epoch/step=79/16200 | loss=1.75367 | ploss=0.82576 | vloss=0.93036 | entropy=-3.68330 | reward=0.31562
# [INFO]  epoch/step=79/16300 | loss=1.84247 | ploss=0.89382 | vloss=0.95113 | entropy=-3.70512 | reward=0.32344
# [INFO]  epoch/step=79/16400 | loss=1.89873 | ploss=0.91426 | vloss=0.98697 | entropy=-3.71997 | reward=0.33469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_79.ckpt
# [INFO]  epoch/step=80/16500 | loss=1.91890 | ploss=0.91694 | vloss=1.00443 | entropy=-3.69554 | reward=0.34156
# [INFO]  epoch/step=80/16600 | loss=1.89662 | ploss=0.89649 | vloss=1.00259 | entropy=-3.68823 | reward=0.34094
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_80.ckpt
# [INFO]  epoch/step=81/16700 | loss=1.83053 | ploss=0.87360 | vloss=0.95940 | entropy=-3.69111 | reward=0.32531
# [INFO]  epoch/step=81/16800 | loss=1.89834 | ploss=0.90003 | vloss=1.00076 | entropy=-3.67833 | reward=0.34031
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_81.ckpt
# [INFO]  epoch/step=82/16900 | loss=1.79473 | ploss=0.85688 | vloss=0.94029 | entropy=-3.66881 | reward=0.31844
# [INFO]  epoch/step=82/17000 | loss=1.83148 | ploss=0.87823 | vloss=0.95573 | entropy=-3.70369 | reward=0.32500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_82.ckpt
# [INFO]  epoch/step=83/17100 | loss=1.82284 | ploss=0.87674 | vloss=0.94856 | entropy=-3.68352 | reward=0.32125
# [INFO]  epoch/step=83/17200 | loss=1.92985 | ploss=0.90944 | vloss=1.02281 | entropy=-3.62568 | reward=0.34781
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_83.ckpt
# [INFO]  epoch/step=84/17300 | loss=1.86211 | ploss=0.88270 | vloss=0.98182 | entropy=-3.64081 | reward=0.33313
# [INFO]  epoch/step=84/17400 | loss=1.91220 | ploss=0.90008 | vloss=1.01454 | entropy=-3.63935 | reward=0.34500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_84.ckpt
# [INFO]  epoch/step=85/17500 | loss=1.86190 | ploss=0.86798 | vloss=0.99634 | entropy=-3.63972 | reward=0.33750
# [INFO]  epoch/step=85/17600 | loss=1.78103 | ploss=0.83230 | vloss=0.95113 | entropy=-3.62290 | reward=0.32344
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_85.ckpt
# [INFO]  epoch/step=86/17700 | loss=1.83250 | ploss=0.84797 | vloss=0.98697 | entropy=-3.65306 | reward=0.33469
# [INFO]  epoch/step=86/17800 | loss=1.75361 | ploss=0.82416 | vloss=0.93183 | entropy=-3.60524 | reward=0.31688
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_86.ckpt
# [INFO]  epoch/step=87/17900 | loss=1.86080 | ploss=0.87071 | vloss=0.99248 | entropy=-3.61211 | reward=0.33656
# [INFO]  epoch/step=87/18000 | loss=1.89746 | ploss=0.89540 | vloss=1.00443 | entropy=-3.58756 | reward=0.34156
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_87.ckpt
# [INFO]  epoch/step=88/18100 | loss=1.76692 | ploss=0.82626 | vloss=0.94304 | entropy=-3.61000 | reward=0.31938
# [INFO]  epoch/step=88/18200 | loss=1.84138 | ploss=0.85583 | vloss=0.98789 | entropy=-3.55510 | reward=0.33594
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_88.ckpt
# [INFO]  epoch/step=89/18300 | loss=1.84466 | ploss=0.86264 | vloss=0.98440 | entropy=-3.59747 | reward=0.33344
# [INFO]  epoch/step=89/18400 | loss=1.82352 | ploss=0.83886 | vloss=0.98697 | entropy=-3.52241 | reward=0.33563
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_89.ckpt
# [INFO]  epoch/step=90/18500 | loss=1.80952 | ploss=0.83336 | vloss=0.97852 | entropy=-3.57032 | reward=0.33125
# [INFO]  epoch/step=90/18600 | loss=1.90095 | ploss=0.89149 | vloss=1.01178 | entropy=-3.54087 | reward=0.34406
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_90.ckpt
# [INFO]  epoch/step=91/18700 | loss=1.89687 | ploss=0.88371 | vloss=1.01546 | entropy=-3.51245 | reward=0.34437
# [INFO]  epoch/step=91/18800 | loss=1.82251 | ploss=0.84064 | vloss=0.98421 | entropy=-3.56166 | reward=0.33469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_91.ckpt
# [INFO]  epoch/step=92/18900 | loss=1.83591 | ploss=0.84171 | vloss=0.99653 | entropy=-3.54263 | reward=0.33719
# [INFO]  epoch/step=92/19000 | loss=1.85845 | ploss=0.85263 | vloss=1.00811 | entropy=-3.49932 | reward=0.34281
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_92.ckpt
# [INFO]  epoch/step=93/19100 | loss=1.84899 | ploss=0.86877 | vloss=0.98256 | entropy=-3.54559 | reward=0.33281
# [INFO]  epoch/step=93/19200 | loss=1.88487 | ploss=0.85885 | vloss=1.02832 | entropy=-3.51311 | reward=0.34969
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_93.ckpt
# [INFO]  epoch/step=94/19300 | loss=1.90414 | ploss=0.87847 | vloss=1.02796 | entropy=-3.49208 | reward=0.34844
# [INFO]  epoch/step=94/19400 | loss=1.81929 | ploss=0.84476 | vloss=0.97686 | entropy=-3.54055 | reward=0.33219
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_94.ckpt
# [INFO]  epoch/step=95/19500 | loss=1.85606 | ploss=0.86203 | vloss=0.99634 | entropy=-3.52761 | reward=0.33750
# [INFO]  epoch/step=95/19600 | loss=1.77050 | ploss=0.81617 | vloss=0.95665 | entropy=-3.52367 | reward=0.32531
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_95.ckpt
# [INFO]  epoch/step=96/19700 | loss=1.81332 | ploss=0.83784 | vloss=0.97778 | entropy=-3.50643 | reward=0.33156
# [INFO]  epoch/step=96/19800 | loss=1.80305 | ploss=0.82386 | vloss=0.98146 | entropy=-3.47888 | reward=0.33375
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_96.ckpt
# [INFO]  epoch/step=97/19900 | loss=1.87732 | ploss=0.86510 | vloss=1.01454 | entropy=-3.52304 | reward=0.34313
# [INFO]  epoch/step=97/20000 | loss=1.86842 | ploss=0.85615 | vloss=1.01454 | entropy=-3.47639 | reward=0.34500
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_97.ckpt
# [INFO]  epoch/step=98/20100 | loss=1.86300 | ploss=0.85475 | vloss=1.01050 | entropy=-3.46072 | reward=0.34250
# [INFO]  epoch/step=98/20200 | loss=1.87734 | ploss=0.86599 | vloss=1.01362 | entropy=-3.48343 | reward=0.34469
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_98.ckpt
# [INFO]  epoch/step=99/20300 | loss=1.83335 | ploss=0.84514 | vloss=0.99046 | entropy=-3.46815 | reward=0.33531
# [INFO]  epoch/step=99/20400 | loss=1.91365 | ploss=0.87283 | vloss=1.04303 | entropy=-3.41777 | reward=0.35469
# [INFO]  epoch/step=99/20500 | loss=1.84930 | ploss=0.84933 | vloss=1.00223 | entropy=-3.46596 | reward=0.33969
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_99.ckpt
# [INFO]  epoch/step=100/20600 | loss=1.88884 | ploss=0.86829 | vloss=1.02281 | entropy=-3.46445 | reward=0.34781
# [INFO]  epoch/step=100/20700 | loss=1.86569 | ploss=0.84968 | vloss=1.01822 | entropy=-3.40711 | reward=0.34625
# [INFO]  Save model to ../save_model/Amazon_Cellphones_Core/lstm/note_rm_w1_p0_g_aiu_0_0_300/policy_model_epoch_100.ckpt
# [INFO]  current time = 20210526-134342

# %%
save_pretrain_model = 1

command = f"python3 ../src/{test_file} --name {exp_name} \
                                        --batch_size {batch_size} \
                                        --gp_setting {gp_setting} \
                                        --model lstm \
                                        --dataset {DATASET} \
                                        --lambda_num {lambda_num} \
                                        --kg_emb_grad {kg_emb_grad} \
                                        --lr {lr} \
                                         --tri_wd_rm {tri_wd_rm} \
                                         --tri_pro_rm {tri_pro_rm} \
                                        --p_hop {p_hop} \
                                        --reasoning_step {reasoning_step} \
                                        --embed_size {embed_size} \
                                        --save_pretrain_model {save_pretrain_model}\
                                        --n_memory {n_memory}"

print(' '.join(command.split()))
# !{command}
# Out:
# python3 ../src/test.py --name note_rm_w1_p0 --batch_size 32 --gp_setting 6_800_15_500_50 --model lstm --dataset cell_core --lambda_num 2.0 --kg_emb_grad 0 --lr 0.0001 --tri_wd_rm 1 --tri_pro_rm 0 --p_hop 2 --reasoning_step 2 --embed_size 32 --n_memory 64
# args.gp_setting =  6_800_15_500_50 args.att_core =  0 args.item_core =  0 args.user_core_th =  6 args.kg_fre_upper =  500 args.max_acts =  50
# label_file =  ../data/Amazon_Cellphones_Core/train_label.pkl
# label_file =  ../data/Amazon_Cellphones_Core/test_label.pkl
# start predict
# Predicting paths...
# len(self.core_user_list) =  6548
# self.args.core_user_list =  6548
# self.user_triplet_list =  6548
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# user embed =  torch.Size([27880, 32])
# embed.requires_grad =  False
# product embed =  torch.Size([10430, 32])
# embed.requires_grad =  False
# word embed =  torch.Size([22494, 32])
# embed.requires_grad =  False
# related_product embed =  torch.Size([101288, 32])
# embed.requires_grad =  False
# brand embed =  torch.Size([956, 32])
# embed.requires_grad =  False
# category embed =  torch.Size([207, 32])
# embed.requires_grad =  False
# r =  setup self_loop
# self_loop embed =  torch.Size([1, 32])
# r =  setup purchase
# purchase embed =  torch.Size([1, 32])
# r =  setup mentions
# mentions embed =  torch.Size([1, 32])
# r =  setup described_as
# described_as embed =  torch.Size([1, 32])
# r =  setup produced_by
# produced_by embed =  torch.Size([1, 32])
# r =  setup belongs_to
# belongs_to embed =  torch.Size([1, 32])
# r =  setup also_bought
# also_bought embed =  torch.Size([1, 32])
# r =  setup also_viewed
# also_viewed embed =  torch.Size([1, 32])
# r =  setup bought_together
# bought_together embed =  torch.Size([1, 32])
# r =  setup padding
# padding embed =  torch.Size([1, 32])
#  12%|████▌                                 | 784/6548 [24:28<2:59:02,  1.86s/it][INFO]  'batch_uids = ', 18742,18467,21495,15912,5342,1616,10300,27731,4573,22098,16595,9158,7253,11075,8325,23457, 800, 800
#  24%|████████▉                            | 1584/6548 [49:22<2:34:42,  1.87s/it][INFO]  'batch_uids = ', 8224,3749,12966,1109,16414,8904,23280,24889,10506,21189,4584,5694,26723,15020,7540,6827, 1600, 1600
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
#  24%|████████▉                            | 1584/6548 [49:56<2:36:29,  1.89s/it]
# NDCG=4.187 |  Recall=5.016 | HR=14.812 | Precision=1.675 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.624 |  Recall=6.315 | HR=18.562 | Precision=1.057 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.684 |  Recall=6.522 | HR=19.188 | Precision=0.877 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.770 |  Recall=6.862 | HR=20.000 | Precision=0.604 | Invalid users=0
# cum_k == 0  0
# start predict
# Predicting paths...
# len(self.core_user_list) =  6548
# self.args.core_user_list =  6548
# self.user_triplet_list =  6548
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# user embed =  torch.Size([27880, 32])
# embed.requires_grad =  False
# product embed =  torch.Size([10430, 32])
# embed.requires_grad =  False
# word embed =  torch.Size([22494, 32])
# embed.requires_grad =  False
# related_product embed =  torch.Size([101288, 32])
# embed.requires_grad =  False
# brand embed =  torch.Size([956, 32])
# embed.requires_grad =  False
# category embed =  torch.Size([207, 32])
# embed.requires_grad =  False
# r =  setup self_loop
# self_loop embed =  torch.Size([1, 32])
# r =  setup purchase
# purchase embed =  torch.Size([1, 32])
# r =  setup mentions
# mentions embed =  torch.Size([1, 32])
# r =  setup described_as
# described_as embed =  torch.Size([1, 32])
# r =  setup produced_by
# produced_by embed =  torch.Size([1, 32])
# r =  setup belongs_to
# belongs_to embed =  torch.Size([1, 32])
# r =  setup also_bought
# also_bought embed =  torch.Size([1, 32])
# r =  setup also_viewed
# also_viewed embed =  torch.Size([1, 32])
# r =  setup bought_together
# bought_together embed =  torch.Size([1, 32])
# r =  setup padding
# padding embed =  torch.Size([1, 32])
#  12%|████▌                                 | 784/6548 [27:50<3:26:10,  2.15s/it][INFO]  'batch_uids = ', 18742,18467,21495,15912,5342,1616,10300,27731,4573,22098,16595,9158,7253,11075,8325,23457, 800, 800
#  24%|████████▉                            | 1584/6548 [56:18<2:57:01,  2.14s/it][INFO]  'batch_uids = ', 8224,3749,12966,1109,16414,8904,23280,24889,10506,21189,4584,5694,26723,15020,7540,6827, 1600, 1600
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
#  24%|████████▉                            | 1584/6548 [56:55<2:58:24,  2.16s/it]
# NDCG=4.325 |  Recall=5.372 | HR=15.062 | Precision=1.749 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.834 |  Recall=6.877 | HR=18.500 | Precision=1.219 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.890 |  Recall=7.070 | HR=19.000 | Precision=1.086 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.926 |  Recall=7.206 | HR=19.375 | Precision=0.926 | Invalid users=0
# cum_k == 0  0
# start predict
# Predicting paths...
# len(self.core_user_list) =  6548
# self.args.core_user_list =  6548
# self.user_triplet_list =  6548
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# user embed =  torch.Size([27880, 32])
# embed.requires_grad =  False
# product embed =  torch.Size([10430, 32])
# embed.requires_grad =  False
# word embed =  torch.Size([22494, 32])
# embed.requires_grad =  False
# related_product embed =  torch.Size([101288, 32])
# embed.requires_grad =  False
# brand embed =  torch.Size([956, 32])
# embed.requires_grad =  False
# category embed =  torch.Size([207, 32])
# embed.requires_grad =  False
# r =  setup self_loop
# self_loop embed =  torch.Size([1, 32])
# r =  setup purchase
# purchase embed =  torch.Size([1, 32])
# r =  setup mentions
# mentions embed =  torch.Size([1, 32])
# r =  setup described_as
# described_as embed =  torch.Size([1, 32])
# r =  setup produced_by
# produced_by embed =  torch.Size([1, 32])
# r =  setup belongs_to
# belongs_to embed =  torch.Size([1, 32])
# r =  setup also_bought
# also_bought embed =  torch.Size([1, 32])
# r =  setup also_viewed
# also_viewed embed =  torch.Size([1, 32])
# r =  setup bought_together
# bought_together embed =  torch.Size([1, 32])
# r =  setup padding
# padding embed =  torch.Size([1, 32])
#  12%|████▌                                 | 784/6548 [28:00<3:26:12,  2.15s/it][INFO]  'batch_uids = ', 18742,18467,21495,15912,5342,1616,10300,27731,4573,22098,16595,9158,7253,11075,8325,23457, 800, 800
#  24%|████████▉                            | 1584/6548 [56:37<2:57:30,  2.15s/it][INFO]  'batch_uids = ', 8224,3749,12966,1109,16414,8904,23280,24889,10506,21189,4584,5694,26723,15020,7540,6827, 1600, 1600
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
#  24%|████████▉                            | 1584/6548 [57:15<2:59:25,  2.17s/it]
# NDCG=4.488 |  Recall=5.617 | HR=15.750 | Precision=1.823 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=4.978 |  Recall=7.057 | HR=19.000 | Precision=1.286 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=5.020 |  Recall=7.203 | HR=19.250 | Precision=1.148 | Invalid users=0
# cum_k == 0  0
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# NDCG=5.063 |  Recall=7.364 | HR=19.688 | Precision=0.977 | Invalid users=0
# cum_k == 0  0
# start predict
# Predicting paths...
# len(self.core_user_list) =  6548
# self.args.core_user_list =  6548
# self.user_triplet_list =  6548
# Load embedding: ../data/Amazon_Cellphones_Core/transe_embed.pkl
# user embed =  torch.Size([27880, 32])
# embed.requires_grad =  False
# product embed =  torch.Size([10430, 32])
# embed.requires_grad =  False
# word embed =  torch.Size([22494, 32])
# embed.requires_grad =  False
# related_product embed =  torch.Size([101288, 32])
# embed.requires_grad =  False
# brand embed =  torch.Size([956, 32])
# embed.requires_grad =  False
# category embed =  torch.Size([207, 32])
# embed.requires_grad =  False
# r =  setup self_loop
# self_loop embed =  torch.Size([1, 32])
# r =  setup purchase
# purchase embed =  torch.Size([1, 32])
# r =  setup mentions
# mentions embed =  torch.Size([1, 32])
# r =  setup described_as
# described_as embed =  torch.Size([1, 32])
# r =  setup produced_by
# produced_by embed =  torch.Size([1, 32])
# r =  setup belongs_to
# belongs_to embed =  torch.Size([1, 32])
# r =  setup also_bought
# also_bought embed =  torch.Size([1, 32])
# r =  setup also_viewed
# also_viewed embed =  torch.Size([1, 32])
# r =  setup bought_together
# bought_together embed =  torch.Size([1, 32])
# r =  setup padding
# padding embed =  torch.Size([1, 32])
#  12%|████▌                                 | 784/6548 [28:40<3:33:21,  2.22s/it][INFO]  'batch_uids = ', 18742,18467,21495,15912,5342,1616,10300,27731,4573,22098,16595,9158,7253,11075,8325,23457, 800, 800
#  15%|█████▊                                | 992/6548 [36:23<3:27:57,  2.25s/it]

# %% [markdown]
# # train UCPR

# %%
load_pretrain_model=1

tri_wd_rm=0
tri_pro_rm=0
exp_name=f"note_rm_w{tri_wd_rm}_p{tri_pro_rm}"

command = f"python3 ../src/{train_file} --reasoning_step {reasoning_step} \
                                         --batch_size {batch_size} \
                                         --name {exp_name} \
                                         --lr {lr} \
                                         --embed_size {embed_size} \
                                         --n_memory {n_memory} \
                                         --load_pretrain_model {load_pretrain_model}  \
                                         --KGE_pretrained {KGE_pretrained} \
                                         --tri_wd_rm {tri_wd_rm} \
                                         --tri_pro_rm {tri_pro_rm} \
                                         --gp_setting {gp_setting} \
                                         --epochs {epochs} \
                                         --KGE_pretrained {KGE_pretrained} \
                                         --lambda_num {lambda_num}  \
                                         --kg_emb_grad {kg_emb_grad} \
                                         --p_hop {p_hop}  \
                                         --reasoning_step {reasoning_step}  \
                                         --model {model} \
                                         --dataset {DATASET}"
print("Running Command:")
print(' '.join(command.split()))
# !{command}

# %%
command = f"python3 ../src/{test_file} --name {exp_name} \
                                        --batch_size {batch_size} \
                                        --gp_setting {gp_setting} \
                                        --model {model} \
                                        --dataset {DATASET} \
                                        --lambda_num {lambda_num} \
                                        --kg_emb_grad {kg_emb_grad} \
                                        --lr {lr} \
                                         --tri_wd_rm {tri_wd_rm} \
                                         --tri_pro_rm {tri_pro_rm} \
                                        --p_hop {p_hop} \
                                        --reasoning_step {reasoning_step} \
                                        --embed_size {embed_size} \
                                        --n_memory {n_memory}"

print(' '.join(command.split()))
# !{command}
